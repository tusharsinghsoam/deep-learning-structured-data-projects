# %%
#importing libraries
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)
# Out:
# 2.13.0

# %% [markdown]
# ## Setup

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from  IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile
import os

# %%
logdir = pathlib.Path('.')/"logs"/"tensorboard_logs"
logdir.mkdir(parents=True, exist_ok = True)
logdir
# Out:
# WindowsPath('logs/tensorboard_logs')

# %%
shutil.rmtree(logdir, ignore_errors=True)

# %% [markdown]
# ## Launch Tensorboard

# %%
# # Load the TensorBoard notebook extension
# %reload_ext tensorboard

# # Open an embedded TensorBoard viewer
# %tensorboard --logdir 'D:/Deep_Learning_Projects/Regression_Fuel_Efficiency/logs/tensorboard_logs/sizes/'

# %% [markdown]
# ## Import and setup data

# %%
# gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz', cache_dir = '.')

# %%
gz = '.\\datasets\\HIGGS.csv.gz'
gz
# Out:
# '.\\datasets\\HIGGS.csv.gz'

# %%
FEATURES = 28
ds = tf.data.experimental.CsvDataset(gz, [float(),]*(FEATURES+1), compression_type="GZIP")

# %%
def pack_row(*row):
    label = row[0]
    features = tf.stack(row[1:],1)
    return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
for row, label in packed_ds.take(1):
    print(row)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %% [markdown]
# ## Define Training procedure

# %%
STEPS_PER_EPOCH
# Out:
# 20

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
    return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0, 100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
    return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200, restore_best_weights=True, verbose=1),
    tf.keras.callbacks.TensorBoard(logdir/name),
    ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
    if optimizer is None:
        optimizer = get_optimizer()
        
    model.compile(optimizer=optimizer,
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                  metrics=[tf.keras.metrics.BinaryCrossentropy(from_logits=True, name='binary_crossentropy'), 'accuracy']
                 )

    model.summary()

    history = model.fit(
                        train_ds,
                        steps_per_epoch = STEPS_PER_EPOCH,
                        epochs=max_epochs,
                        validation_data=validate_ds,
                        callbacks=get_callbacks(name),
                        verbose=0
    )
    return history

# %% [markdown]
# ## Tiny Model

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                464
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 481 (1.88 KB)
# Trainable params: 481 (1.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4853,  binary_crossentropy:0.7628,  loss:0.7628,  val_accuracy:0.4570,  val_binary_crossentropy:0.7578,  val_loss:0.7578,
# ....................................................................................................
# Epoch: 100, accuracy:0.5869,  binary_crossentropy:0.6318,  loss:0.6318,  val_accuracy:0.5810,  val_binary_crossentropy:0.6310,  val_loss:0.6310,
# ....................................................................................................
# Epoch: 200, accuracy:0.6034,  binary_crossentropy:0.6240,  loss:0.6240,  val_accuracy:0.6000,  val_binary_crossentropy:0.6244,  val_loss:0.6244,
# ....................................................................................................
# Epoch: 300, accuracy:0.6091,  binary_crossentropy:0.6169,  loss:0.6169,  val_accuracy:0.6100,  val_binary_crossentropy:0.6171,  val_loss:0.6171,
# ....................................................................................................
# Epoch: 400, accuracy:0.6281,  binary_crossentropy:0.6089,  loss:0.6089,  val_accuracy:0.6160,  val_binary_crossentropy:0.6067,  val_loss:0.6067,
# ....................................................................................................
# Epoch: 500, accuracy:0.6397,  binary_crossentropy:0.6027,  loss:0.6027,  val_accuracy:0.6210,  val_binary_crossentropy:0.5989,  val_loss:0.5989,
# ....................................................................................................
# Epoch: 600, accuracy:0.6511,  binary_crossentropy:0.5977,  loss:0.5977,  val_accuracy:0.6270,  val_binary_crossentropy:0.5956,  val_loss:0.5956,
# ....................................................................................................
# Epoch: 700, accuracy:0.6577,  binary_crossentropy:0.5942,  loss:0.5942,  val_accuracy:0.6530,  val_binary_crossentropy:0.5946,  val_loss:0.5946,
# ....................................................................................................
# Epoch: 800, accuracy:0.6602,  binary_crossentropy:0.5910,  loss:0.5910,  val_accuracy:0.6320,  val_binary_crossentropy:0.5948,  val_loss:0.5948,
# ....................................................................................................
# Epoch: 900, accuracy:0.6612,  binary_crossentropy:0.5881,  loss:0.5881,  val_accuracy:0.6480,  val_binary_crossentropy:0.5928,  val_loss:0.5928,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6658,  binary_crossentropy:0.5859,  loss:0.5859,  val_accuracy:0.6480,  val_binary_crossentropy:0.5923,  val_loss:0.5923,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6708,  binary_crossentropy:0.5842,  loss:0.5842,  val_accuracy:0.6450,  val_binary_crossentropy:0.5922,  val_loss:0.5922,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6670,  binary_crossentropy:0.5825,  loss:0.5825,  val_accuracy:0.6440,  val_binary_crossentropy:0.5910,  val_loss:0.5910,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6702,  binary_crossentropy:0.5805,  loss:0.5805,  val_accuracy:0.6430,  val_binary_crossentropy:0.5898,  val_loss:0.5898,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6733,  binary_crossentropy:0.5788,  loss:0.5788,  val_accuracy:0.6480,  val_binary_crossentropy:0.5888,  val_loss:0.5888,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6729,  binary_crossentropy:0.5774,  loss:0.5774,  val_accuracy:0.6590,  val_binary_crossentropy:0.5872,  val_loss:0.5872,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6750,  binary_crossentropy:0.5763,  loss:0.5763,  val_accuracy:0.6750,  val_binary_crossentropy:0.5861,  val_loss:0.5861,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6738,  binary_crossentropy:0.5753,  loss:0.5753,  val_accuracy:0.6600,  val_binary_crossentropy:0.5872,  val_loss:0.5872,
# ....................................................................................................
# Epoch: 1800, accuracy:0.6755,  binary_crossentropy:0.5745,  loss:0.5745,  val_accuracy:0.6750,  val_binary_crossentropy:0.5849,  val_loss:0.5849,
# ....................................................................................................
# Epoch: 1900, accuracy:0.6746,  binary_crossentropy:0.5746,  loss:0.5746,  val_accuracy:0.6650,  val_binary_crossentropy:0.5871,  val_loss:0.5871,
# ....................................................................................................
# Epoch: 2000, accuracy:0.6773,  binary_crossentropy:0.5730,  loss:0.5730,  val_accuracy:0.6730,  val_binary_crossentropy:0.5858,  val_loss:0.5858,
# ....................................................................................................
# Epoch: 2100, accuracy:0.6789,  binary_crossentropy:0.5724,  loss:0.5724,  val_accuracy:0.6750,  val_binary_crossentropy:0.5853,  val_loss:0.5853,
# ....................................................................................................
# Epoch: 2200, accuracy:0.6758,  binary_crossentropy:0.5718,  loss:0.5718,  val_accuracy:0.6790,  val_binary_crossentropy:0.5845,  val_loss:0.5845,
# ..............................................................................Restoring model weights from the end of the best epoch: 2078.
# Epoch 2278: early stopping

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.55, 0.7]);

# %% [markdown]
# ## Small Model

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 16)                464
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 753 (2.94 KB)
# Trainable params: 753 (2.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4906,  binary_crossentropy:0.7322,  loss:0.7322,  val_accuracy:0.4670,  val_binary_crossentropy:0.7056,  val_loss:0.7056,
# ....................................................................................................
# Epoch: 100, accuracy:0.6266,  binary_crossentropy:0.6102,  loss:0.6102,  val_accuracy:0.6090,  val_binary_crossentropy:0.6146,  val_loss:0.6146,
# ....................................................................................................
# Epoch: 200, accuracy:0.6607,  binary_crossentropy:0.5887,  loss:0.5887,  val_accuracy:0.6240,  val_binary_crossentropy:0.5962,  val_loss:0.5962,
# ....................................................................................................
# Epoch: 300, accuracy:0.6769,  binary_crossentropy:0.5769,  loss:0.5769,  val_accuracy:0.6520,  val_binary_crossentropy:0.5892,  val_loss:0.5892,
# ....................................................................................................
# Epoch: 400, accuracy:0.6881,  binary_crossentropy:0.5698,  loss:0.5698,  val_accuracy:0.6560,  val_binary_crossentropy:0.5893,  val_loss:0.5893,
# ....................................................................................................
# Epoch: 500, accuracy:0.6925,  binary_crossentropy:0.5657,  loss:0.5657,  val_accuracy:0.6610,  val_binary_crossentropy:0.5894,  val_loss:0.5894,
# ....................................................................................................
# Epoch: 600, accuracy:0.6952,  binary_crossentropy:0.5619,  loss:0.5619,  val_accuracy:0.6550,  val_binary_crossentropy:0.5888,  val_loss:0.5888,
# ....................Restoring model weights from the end of the best epoch: 420.
# Epoch 620: early stopping

# %% [markdown]
# ## Medium Model

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                1856
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 10241 (40.00 KB)
# Trainable params: 10241 (40.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4844,  binary_crossentropy:0.7044,  loss:0.7044,  val_accuracy:0.4880,  val_binary_crossentropy:0.6806,  val_loss:0.6806,
# ....................................................................................................
# Epoch: 100, accuracy:0.6993,  binary_crossentropy:0.5449,  loss:0.5449,  val_accuracy:0.6450,  val_binary_crossentropy:0.6193,  val_loss:0.6193,
# ....................................................................................................
# Epoch: 200, accuracy:0.7693,  binary_crossentropy:0.4575,  loss:0.4575,  val_accuracy:0.6320,  val_binary_crossentropy:0.6813,  val_loss:0.6813,
# ......................................................................Restoring model weights from the end of the best epoch: 70.
# Epoch 270: early stopping

# %% [markdown]
# ## Large Model

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 512)               14848
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dense_11 (Dense)            (None, 512)               262656
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  dense_13 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803329 (3.06 MB)
# Trainable params: 803329 (3.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5085,  binary_crossentropy:0.7626,  loss:0.7626,  val_accuracy:0.5390,  val_binary_crossentropy:0.6766,  val_loss:0.6766,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0018,  loss:0.0018,  val_accuracy:0.6700,  val_binary_crossentropy:1.7816,  val_loss:1.7816,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6710,  val_binary_crossentropy:2.3942,  val_loss:2.3942,
# ...............................Restoring model weights from the end of the best epoch: 31.
# Epoch 231: early stopping

# %% [markdown]
# ## Plot the training and validation losses

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.8])
plt.xlabel("Epochs [Log Scale]");

# %% [markdown]
# ## Strategies to Prevent Overfitting

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %% [markdown]
# ### L2 Weight Regularization

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 512)               14848
#
#  dense_15 (Dense)            (None, 512)               262656
#
#  dense_16 (Dense)            (None, 512)               262656
#
#  dense_17 (Dense)            (None, 512)               262656
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803329 (3.06 MB)
# Trainable params: 803329 (3.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5029,  binary_crossentropy:0.8245,  loss:2.3552,  val_accuracy:0.4690,  val_binary_crossentropy:0.6874,  val_loss:2.1440,
# ....................................................................................................
# Epoch: 100, accuracy:0.6521,  binary_crossentropy:0.5982,  loss:0.6216,  val_accuracy:0.6500,  val_binary_crossentropy:0.5971,  val_loss:0.6203,
# ....................................................................................................
# Epoch: 200, accuracy:0.6709,  binary_crossentropy:0.5806,  loss:0.6033,  val_accuracy:0.6650,  val_binary_crossentropy:0.5785,  val_loss:0.6012,
# ....................................................................................................
# Epoch: 300, accuracy:0.6830,  binary_crossentropy:0.5732,  loss:0.5966,  val_accuracy:0.6800,  val_binary_crossentropy:0.5776,  val_loss:0.6012,
# ....................................................................................................
# Epoch: 400, accuracy:0.6959,  binary_crossentropy:0.5623,  loss:0.5877,  val_accuracy:0.6810,  val_binary_crossentropy:0.5761,  val_loss:0.6014,
# ....................................................................................................
# Epoch: 500, accuracy:0.7010,  binary_crossentropy:0.5559,  loss:0.5828,  val_accuracy:0.6770,  val_binary_crossentropy:0.5754,  val_loss:0.6026,
# ....................................................................................................
# Epoch: 600, accuracy:0.6984,  binary_crossentropy:0.5525,  loss:0.5805,  val_accuracy:0.6940,  val_binary_crossentropy:0.5703,  val_loss:0.5985,
# ....................................................................................................
# Epoch: 700, accuracy:0.7098,  binary_crossentropy:0.5425,  loss:0.5721,  val_accuracy:0.6950,  val_binary_crossentropy:0.5791,  val_loss:0.6085,
# ....................................................................................................
# Epoch: 800, accuracy:0.7109,  binary_crossentropy:0.5355,  loss:0.5655,  val_accuracy:0.6840,  val_binary_crossentropy:0.5774,  val_loss:0.6076,
# ...........Restoring model weights from the end of the best epoch: 611.
# Epoch 811: early stopping

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %% [markdown]
# ### Dropout Model

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 512)               14848
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_21 (Dense)            (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_22 (Dense)            (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_23 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803329 (3.06 MB)
# Trainable params: 803329 (3.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5105,  binary_crossentropy:0.7913,  loss:0.7913,  val_accuracy:0.5640,  val_binary_crossentropy:0.6821,  val_loss:0.6821,
# ....................................................................................................
# Epoch: 100, accuracy:0.6579,  binary_crossentropy:0.5952,  loss:0.5952,  val_accuracy:0.6930,  val_binary_crossentropy:0.5839,  val_loss:0.5839,
# ....................................................................................................
# Epoch: 200, accuracy:0.6867,  binary_crossentropy:0.5576,  loss:0.5576,  val_accuracy:0.6860,  val_binary_crossentropy:0.5839,  val_loss:0.5839,
# ....................................................................................................
# Epoch: 300, accuracy:0.7231,  binary_crossentropy:0.5115,  loss:0.5115,  val_accuracy:0.6910,  val_binary_crossentropy:0.6068,  val_loss:0.6068,
# .......................Restoring model weights from the end of the best epoch: 123.
# Epoch 323: early stopping

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %% [markdown]
# ### Combined L2+Dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 512)               14848
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_25 (Dense)            (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_26 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_27 (Dense)            (None, 512)               262656
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_28 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803329 (3.06 MB)
# Trainable params: 803329 (3.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5127,  binary_crossentropy:0.7994,  loss:0.9578,  val_accuracy:0.5120,  val_binary_crossentropy:0.6694,  val_loss:0.8270,
# ....................................................................................................
# Epoch: 100, accuracy:0.6472,  binary_crossentropy:0.6035,  loss:0.6336,  val_accuracy:0.6480,  val_binary_crossentropy:0.5846,  val_loss:0.6145,
# ....................................................................................................
# Epoch: 200, accuracy:0.6702,  binary_crossentropy:0.5863,  loss:0.6122,  val_accuracy:0.6890,  val_binary_crossentropy:0.5736,  val_loss:0.5995,
# ....................................................................................................
# Epoch: 300, accuracy:0.6723,  binary_crossentropy:0.5846,  loss:0.6133,  val_accuracy:0.6850,  val_binary_crossentropy:0.5706,  val_loss:0.5993,
# ....................................................................................................
# Epoch: 400, accuracy:0.6779,  binary_crossentropy:0.5784,  loss:0.6091,  val_accuracy:0.6900,  val_binary_crossentropy:0.5536,  val_loss:0.5843,
# ....................................................................................................
# Epoch: 500, accuracy:0.6840,  binary_crossentropy:0.5705,  loss:0.6031,  val_accuracy:0.6890,  val_binary_crossentropy:0.5531,  val_loss:0.5858,
# ....................................................................................................
# Epoch: 600, accuracy:0.6883,  binary_crossentropy:0.5628,  loss:0.5970,  val_accuracy:0.6910,  val_binary_crossentropy:0.5527,  val_loss:0.5869,
# ....................................................................................................
# Epoch: 700, accuracy:0.6879,  binary_crossentropy:0.5618,  loss:0.5989,  val_accuracy:0.6780,  val_binary_crossentropy:0.5472,  val_loss:0.5843,
# ....................................................................................................
# Epoch: 800, accuracy:0.6905,  binary_crossentropy:0.5586,  loss:0.5974,  val_accuracy:0.6770,  val_binary_crossentropy:0.5610,  val_loss:0.5997,
# ....................................................................................................
# Epoch: 900, accuracy:0.6951,  binary_crossentropy:0.5538,  loss:0.5941,  val_accuracy:0.6910,  val_binary_crossentropy:0.5562,  val_loss:0.5965,
# ...........................................................................Restoring model weights from the end of the best epoch: 775.
# Epoch 975: early stopping

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)
